# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Dates management
import datetime

# Visualization library
import altair as alt

# Data manipulation library
import pandas as pd

# Enable Altair to display all rows of data
alt.data_transformers.enable('default', max_rows=None)
# Out:
# DataTransformerRegistry.enable('default')

# %%
df_person = pd.read_pickle('datap/df_person_fix.pkl')
# Visits
df_visit = pd.read_pickle('datap/df_visit.pkl')
# Diagnosis (condition)
df_cond = pd.read_pickle('datap/df_condition.pkl')
# Medication
df_bio_fix_final= pd.read_pickle('datap/df_bio_fix_final.pkl')

df_note = pd.read_pickle('datap/df_note.pkl')

df_analyse = pd.read_pickle('datap/df_analyse.pkl')

# %%
print(f"We have {df_person.person_id.nunique()} unique patient ids in this dataset.")
# Out:
# We have 1530 unique patient ids in this dataset.

# %%
df_value_count = df_analyse.person_id.value_counts()
n_numerous = df_value_count[df_value_count > 1].size
print(f"{n_numerous} patients have more than one visit")
# Out:
# 1494 patients have more than one visit

# %%
df_note.info()
df_note.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1547 entries, 0 to 1546
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   visit_occurrence_id  1547 non-null   float64
#  1   note_datetime        1547 non-null   datetime64[ns]
#  2   note_id              1547 non-null   float64
#  3   cdm_source           1547 non-null   object
#  4   note_text            1547 non-null   object
# dtypes: datetime64[ns](1), float64(2), object(2)
# memory usage: 60.6+ KB
#    visit_occurrence_id note_datetime     note_id cdm_source  \
# 0           82113087.0    2024-02-19  83854216.0      EHR 1
# 1           84162050.0    2022-12-02  87336601.0      EHR 1
# 2           88991591.0    2020-10-20  80825304.0      EHR 1
# 3           87431501.0    2020-03-29  82508858.0      EHR 1
# 4           80285786.0    2022-01-30  88418144.0      EHR 1
#
#                                            note_text
# 0
# 1  Compte rendu de consultation\n\nPatient : [Nom...
# 2  Compte rendu de consultation\n\nPatient : [Nom...
# 3  Compte rendu de consultation\n\nPatient : [Nom...
# 4

# %%
nulls=df_note['note_text'].str.strip().fillna('').eq('').sum()
print(nulls)
# Out:
# 613

# %%
df_note_fix = df_note[df_note['note_text'].str.strip().fillna('').ne('')]

# %%
print(df_note_fix.sample(1)['note_text'].squeeze())
# Out:
# Compte rendu de consultation
#
# Patient : [Nom du patient]
# Âge : [Âge du patient]
# Sexe : [Sexe du patient]
# Numéro de dossier : [Numéro de dossier du patient]
#
# Motif de la consultation:
# Des recommandations ont été fournies à la patiente concernant la gestion des effets secondaires de l'hormonothérapie, tels que les bouffées de chaleur, les douleurs articulaires et les changements d'humeur. Des stratégies non pharmacologiques et pharmacologiques ont été discutées.
#
# Antecedents familiaux :
# La patiente a mentionné que ses parents n'ont pas de frères ou de sœurs, ce qui limite davantage les antécédents familiaux de cancer du sein.
#
# Histoire de la maladie:
# Après le diagnostic, la patiente a été référée à un spécialiste en oncologie pour une évaluation et une gestion plus approfondies.
#
# Examen du patient:
#
#
# Plan de traitement:
# La patiente bénéficiera d'un suivi régulier avec un spécialiste en oncologie médicale pour évaluer l'efficacité du traitement, gérer les effets secondaires éventuels et ajuster le plan thérapeutique si nécessaire.
#
# Signature du médecin :
# [Nom du médecin]
# [Titre/Spécialité]
# [Hôpital/Service]
